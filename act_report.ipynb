# %% [markdown]
# # Act Report by Agbons Ekata-Inuaghata

# %% [markdown]
# ### I am not a big fan of dogs but many people are so fond of dogs that they have numerous dogs as pets and suprisingly some few even went the extra mile of rating dogs on twitter which is quite fascinating

# %% [markdown]
# ### A twitter account named WeRateDogs rates dogs over a standard denominator of 10 and the numerator is always above 10 because the owner of account considers all dogs as good dogs. This account has accumulated huge following on twitter and also international media coverage

# %% [markdown]
# ### I have wrangled the data from the WeRateDogs twitter account to provide answers to insightful questions which include which dog breed is the most popular, which dog stage has the most retweets, and which dog breed has thenmostblikes. Python librabries helped me in coming up with visualizations in order to draw insights from my analysis

# %% [markdown]
# ## Most Popular Dog Breeds

# %% [markdown]
# ### I analysed the twitter data based on the first prediction column and these were the most popular dog breeds

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### This analysis gave me an insight on the data which is Golden Retriever being the most popular dog breed

# %% [markdown]
# ## Most Popular Dog Stage by Retweet Count

# %%
sb.set_style('whitegrid')
plt.figure(figsize = (15,6))
sb.barplot(data = frequency, x = frequency.stage, y = frequency.retweet_mean, color = base_color, 
           order = frequency.sort_values('retweet_mean', ascending = False).stage);
plt.xticks(rotation=90);
sb.set(font_scale = 2);
plt.xlabel("Dog Stage",fontsize = 22);
plt.ylabel("Retweet Mean",fontsize = 18);
plt.title("Dog Stage and Retweets",fontsize = 18);

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### This analysis gave me an insight on the data which puppo stage being the most popular by retweet count

# %% [markdown]
# ## Most Popular Dog Breed by Favorite Count

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### This analysis gave me an insight on the data which Samoyed being the most popular by favorite count
